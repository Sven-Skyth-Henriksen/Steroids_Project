# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from dateutil.parser import parse
import matplotlib.pyplot as plt
import numpy as np

# %%
###### Website: bodybuilding-data.com ######

# %%
#creating a dictionary for 
#ANABOLIC ANDROGENIC STEROIDS

data = {'Name': ['Oxandrolone','Methandienone','Stanozolol (oral)','Oxymetholone','Masterolone','Methyltestosterone',
                'Turinabol','Stanozolol (injectable)','Nandrolone Decanoate','Boldenone Undecylenate'],
        
        'Trade names': ['Anavar','Metan, Dianabol, Bionabol, Napusim','Stromba, Stanabol, Winstrol','Anapolon, Anadrol',
                       'Proviron, Provibol','Metiltestosteron, Testosteron-oral','Oral-Turinabol','Winstrol',
                       'Deca, Deca-Durabolin, Decabol','Boldenone, Equipoise'],
        
        'Category': ['Anabolic Steroid',' Anabolic Steroid','Anabolic Steroid','Anabolic Steroid','Anabolic Steroid','Anabolic Steroid',
                    'Anabolic Steroid','Anabolic Steroid','Anabolic Steroid'],
        
        'Type':['oral','oral','oral','oral','oral','oral','oral','injection (water solution)','injection'],
        
        'Discovered': ['1964','1952','1962','1960','1960','1935','1961','1962','1962'],
        
        'Androgenic / Anabolic ratio compared with the testosterone':['45/320','40-60 / 90-120','30 / 320','24/322-630',
                                                                     '100-150 / 30-40','115-150 / 94-130','10 / 100',
                                                                     '30 / 320','37 / 125'],
        
        'Half-Life': [np.nan,'4 hours','8 hours', np.nan, np.nan,'6 hours','16 hours','8 hours','6 days'],
        
        
        'Action time': ['8-12 houre',np.nan, np.nan,'16 hours','12 hours',np.nan,np.nan,np.nan,'2-3 weeks'],
        
        'Detection time':['3 weeks','5 month','3 weeks','2 months','5-6 weeks','4-6 weeks','6 weeks','2 months','18 months'],
        
        'Derivative of':['DHT','testosterone','DHT','DHT','DHT','testosterone','testosterone','DHT','testosterone'],
        
        'Aromatase': ['no','yes','no','no','no','yes','no','no','no'],
        
       'Convertion into DHT':['no','no','no','no','no','yes','no','no','no'],
        
       'Water retention': ['no','yes','no','yes','no','no','no','no','no'],
        
       'Toxic':['weak','strong','strong','strong','weak','weak','strong','weak','weak'],
        
       'Optimal dosage':['20-40mg daily','30-60mg daily','30-50mg daily','50-100mg daily','50-100mg daily','50-100mg daily',
                        '20-40mg daily','150-300mg weekly','400-600mg weekly'],
        
       'Common side effects':['hair loss','gynecomastia, liver illness','hair loss, acne, up cholesterol levels, liver illness',
                             'gynecomastia, acne, hair loss, liver illness','increased body hair growth','gynecomastia, acne',
                             'liver illness','hair loss, acne, up cholesterol levels, liver illness','low libido'
                             ]
       }

#creating a table

anabolic = pd.DataFrame(data, columns = ['Name','Trade names','Category','Type','Discovered','Androgenic / Anabolic ratio compared with the testosterone', 
                                   'Action time','Half-Life','Detection time','Derivative of','Aromatase','Convertion into DHT',
                                  'Water retention','Toxic','Optimal dosage','Common side effects'])

display(anabolic)
# Out:
#                       Name                         Trade names  \
# 0              Oxandrolone                              Anavar
# 1            Methandienone  Metan, Dianabol, Bionabol, Napusim
# 2        Stanozolol (oral)         Stromba, Stanabol, Winstrol
# 3             Oxymetholone                   Anapolon, Anadrol
# 4              Masterolone                  Proviron, Provibol
# 5       Methyltestosterone  Metiltestosteron, Testosteron-oral
# 6                Turinabol                      Oral-Turinabol
# 7  Stanozolol (injectable)                            Winstrol
# 8     Nandrolone Decanoate       Deca, Deca-Durabolin, Decabol
#
#             Category                        Type Discovered  \
# 0   Anabolic Steroid                        oral       1964
# 1   Anabolic Steroid                        oral       1952
# 2   Anabolic Steroid                        oral       1962
# 3   Anabolic Steroid                        oral       1960
# ...
